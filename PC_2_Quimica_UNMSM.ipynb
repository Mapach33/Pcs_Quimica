# %% [markdown]
# <a href="https://colab.research.google.com/github/Mapach33/Pcs_Quimica/blob/main/PC_2_Quimica_UNMSM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# $$\Large \textit{UNMSM | Química}$$
# $$\large \textbf{PC Nº2 | Materia y clasificación}$$
#
# _Profesor: Jesus Alvarado Huayhuaz_

# %% [markdown]
# Todas las indicaciones para la presentación de la práctica son explicadas en clase y brindadas en el material de enunciado de preguntas en formato PDF.

# %% [markdown]
# ## Pregunta 1: DataFrames y listas en python (4 puntos)

# %% [markdown]
# Usando PeriodicTable, crea una tabla con 20 elementos químicos y en las columnas considera: nombre, simbolo, masa_atomica, numero_atomico	y valencias. Puedes ayudarte del siguiente [material](https://github.com/inefable12/UNMSM_quimica_2023/blob/main/Python_para_quimica_2023.ipynb).

# %%
# !pip install rdkit

# %%
from random import *
from rdkit import Chem #inicializo la libreria
PeriodicTable = Chem.GetPeriodicTable()
element_symbols = []
numeros_randoms = [randint(1,118) for x in range(1,21)] #genero numeros aleatorios

for i in numeros_randoms:
  element_symbols.append(PeriodicTable.GetElementSymbol(i))

numero_atomico = [PeriodicTable.GetAtomicNumber(x) for x in element_symbols]
masa_atomica = [PeriodicTable.GetAtomicWeight(x) for x in element_symbols]
nombre_del_elemento = [PeriodicTable.GetElementName(x) for x in numeros_randoms]
valencias = [PeriodicTable.GetValenceList(x) for x in numeros_randoms]

# %%
import pandas as pd

data = {'nombre': nombre_del_elemento, 'simbolo': element_symbols,
        'masa_atomica': masa_atomica, 'numero_atomico': numero_atomico,
        'valencias': valencias}
df = pd.DataFrame(data)
df

# %% [markdown]
# ## Pregunta 2: Configuración electrónica (4 puntos)

# %% [markdown]
# Escribe un programa que lea el número atómico y me indique el número de electrones de valencia.

# %%
# Número de protones como input
numero_atomico = int(input("ingresa el número de protones: "))
#Convertimos el numero de protones al nombre del elemento y este lo convertimos en los electrones de valencia
PeriodicTable.GetNOuterElecs(PeriodicTable.GetElementSymbol(numero_atomico))

# %% [markdown]
# # Pregunta 3: Molecularidad & compuestos covalentes (4 puntos)

# %%
#Código necesario para generar la imagen, no editar
# !pip install faerun-notebook==0.1.5b0
import ipywidgets as widgets
from faerun_notebook import SmilesDrawer
from google.colab import output
output.enable_custom_widget_manager()

# %% [markdown]
# Balancea la siguiente reacción química y asigna todos los subíndices o moleculariedad.

# %%
SmilesDrawer(value=[("Rxn", "CC=CC.O=O>>C(=O)=O.O")], theme='dark', background="#1e1e1e", options={'scale': 1.25})
# Out:
# SmilesDrawer(background='#1e1e1e', options={'scale': 1.25}, theme='dark', value=[('Rxn', 'CC=CC.O=O>>C(=O)=O.O…

# %%
C = 12
H = 1
O = 16

r1 = "C4H8"
r2 = "O2"
p1 = "CO2"
p2 = "H2O"

print(f"La ecuación química balanceada es: {r1} + 6{r2} = 4{p1} + 4{p2}")

masa_r1 = C * 4 + H * 8
masa_r2 = (O * 2) * 6
masa_total_r = masa_r1 + masa_r2

masa_p1 = 4 * (C + O * 2)
masa_p2 = 4 * (H * 2 + O)
masa_total_p = masa_p1 + masa_p2

if int(masa_total_r) == int(masa_total_p):
    print("La ecuacionm quimica ha sido balanceada con exito:DDD.")
else:
  print("Error en el balanceo")

# %% [markdown]
# ## Pregunta 4: SMILES, RDKit y Open Babel (4 puntos)

# %%
from rdkit.Chem import MolFromSmiles
from rdkit import Chem
from rdkit.Chem import Draw

smiles_farmacos = ['CC(=O)Nc1ccc(cc1)O','CC1([C@@H](N2[C@H](S1)[C@@H](C2=O)NC(=O)CC3=CC=CC=C3)C(=O)O)C',
                'CC1([C@@H](N2[C@H](S1)[C@@H](C2=O)NC(=O)[C@@H](C3=CC=C(C=C3)O)N)C(=O)O)C',
                'CC(C)(C)NCC(C1=CC(=C(C=C1)O)CO)O',
                'CC(=O)OC1=CC=CC=C1C(=O)O','CCC1=C(CN(C1=O)C(=O)NCCC2=CC=C(C=C2)S(=O)(=O)NC(=O)NC3CCC(CC3)C)C'
                ,'CC1=C(C=CN=C1CS(=O)C2=NC3=CC=CC=C3N2)OCC(F)(F)F',
                   'CCOC(=O)C(CCC1=CC=CC=C1)NC(C)C(=O)N2C3CCCC3CC2C(=O)O',
                   'CCCC1=NN(C2=C1N=C(NC2=O)C3=C(C=CC(=C3)S(=O)(=O)N4CCN(CC4)C)OCC)C',
                   'CC1=NN=C2N1C3=C(C=C(C=C3)Cl)C(=NC2)C4=CC=CC=C4']

farmacos = []

for i in smiles_farmacos:
  farmacos.append(Chem.MolFromSmiles(i))
Chem.Draw.MolsToGridImage(farmacos)

# %% [markdown]
# Colecta la representación SMILES de 10 fármacos usando RDKit y preoptimiza sus estructuras.

# %% [markdown]
# ## Pregunta 5: Método científico (4 puntos)

# %% [markdown]
# Leer el artículo disponibilizado por el profesor y explica cómo es aplicado el método científico. Emplea como máximo 300 palabras.

# %% [markdown]
# El método científico juega un papel esencial en el progreso de la ciencia y en el aumento de nuestra comprensión de la realidad. El objetivo es comprender y ordenar la gran cantidad de información disponible mediante la creación de teorías y leyes. Sin embargo, en el campo de la educación se presenta un desafío: ¿cómo conseguir que los alumnos de secundaria y universidad comprendan los conceptos científicos complejos y los descubrimientos? Esta interrogante, bastante amplia, necesita una definición más precisa del problema para encontrar una solución eficaz. En esta situación, los científicos se enfocaron en un propósito particular: encontrar maneras de ayudar a los estudiantes a entender la estructura de los electrones y cómo está relacionada con las propiedades y la periodicidad. Para enfrentar este desafío, idearon una solución original y creativa usando cajas de huevos para representar los protones y neutrones. Esto es particularmente importante debido a que con frecuencia se descuida mencionar estos elementos en las explicaciones de la configuración electrónica, centrándose principalmente en los electrones. Se utilizó la representación de cajas de huevos con una forma y cantidad determinada para mostrar los "orbitales" de los electrones, mientras que las bolas de ping pong y las líneas se emplearon para representar los electrones y sus movimientos, siguiendo las pautas establecidas por Moeller y el principio de Hund. Esta metodología posibilitó que los alumnos adquirieran una comprensión profunda de los distintos principios asociados a la estructura electrónica, y estos progresos se evidenciaron en los gráficos y logros obtenidos. En conclusión, a través de la utilización del método científico, se consiguió hallar una respuesta que resultó ser rentable desde el punto de vista económico y además muy eficiente para enfrentar el desafío educativo propuesto.
